# %% [markdown]
# # This is a sample Jupyter Notebook
#
# Below is an example of a code cell.
# Put your cursor into the cell and press Shift+Enter to execute it and select the next one, or click 'Run Cell' button.
#
# Press Double Shift to search everywhere for classes, files, tool windows, actions, and settings.
#
# To learn more about Jupyter Notebooks in PyCharm, see [help](https://www.jetbrains.com/help/pycharm/ipython-notebook-support.html).
# For an overview of PyCharm, go to Help -> Learn IDE features or refer to [our documentation](https://www.jetbrains.com/help/pycharm/getting-started.html).

# %%
# !pip install yfinance
# !pip install pandas
# !pip install requests
# !pip install bs4
# !pip install plotly
# !pip install html5lib

import yfinance as yf
import pandas as pd
import requests
from bs4 import BeautifulSoup
import plotly.graph_objects as go

def make_graph(data, title):
    fig = go.Figure()
    fig.add_trace(go.Scatter(x=data["Date"], y=data["Close"], mode="lines", name="Close Price"))
    fig.update_layout(
        title=title,
        xaxis_title="Date",
        yaxis_title="Stock Price (USD)",
        template="plotly_dark"
    )
    fig.show()





tesla = yf.Ticker("TSLA")
tesla_data = tesla.history(period="max")
tesla_data.reset_index(inplace=True)
tesla_data.head()


url= "https://www.macrotrends.net/stocks/charts/TSLA/tesla/revenue"
headers = {"User-Agent": "Mozilla/5.0"}
response = requests.get(url, headers=headers)

soup = BeautifulSoup(response.text, "html.parser")

tables = soup.find_all("table")
revenue_table = None
for table in tables:
    if "Tesla Quarterly Revenue" in table.text:
        revenue_table = table
        break

data = []
rows = revenue_table.find_all("tr")[1:]
for row in rows:
    cols = row.find_all("td")
    date = cols[0].text.strip()
    revenue = cols[1].text.strip().replace("$", "").replace(",", "")
    if revenue:
        data.append([date, float(revenue)])

tesla_revenue = pd.DataFrame(data, columns=["Date", "Revenue"])

print(tesla_revenue.tail())


gamestop = yf.Ticker("GME")
gme_data=gamestop.history(period="max")
gme_data.reset_index(inplace=True)
gme_data.head()


url2 = "https://www.macrotrends.net/stocks/charts/GME/gamestop/revenue"
headers = {"User-Agent": "Mozilla/5.0"}
response = requests.get(url2, headers=headers)

soup = BeautifulSoup(response.text, "html.parser")

tables = soup.find_all("table")
revenue_table = None
for table in tables:
    if "GameStop Quarterly Revenue" in table.text:
        revenue_table = table
        break

data = []
rows = revenue_table.find_all("tr")[1:]
for row in rows:
    cols = row.find_all("td")
    date = cols[0].text.strip()
    revenue = cols[1].text.strip().replace("$", "").replace(",", "")
    if revenue:
        data.append([date, float(revenue)])

gme_revenue = pd.DataFrame(data, columns=["Date", "Revenue"])

print(gme_revenue.tail())


make_graph(tesla_data, "Tesla Stock Price Over Time")


make_graph(gme_data, "GameStop Stock Price Over Time")
# Out:
# Collecting yfinance
#   Using cached yfinance-0.2.65-py2.py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\j_riv\pycharmprojects\jupyterproject\.venv\lib\site-packages (from yfinance) (2.3.1)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\j_riv\pycharmprojects\jupyterproject\.venv\lib\site-packages (from yfinance) (2.3.2)
# Requirement already satisfied: requests>=2.31 in c:\users\j_riv\pycharmprojects\jupyterproject\.venv\lib\site-packages (from yfinance) (2.32.4)
# Collecting multitasking>=0.0.7 (from yfinance)
#   Using cached multitasking-0.0.12-py3-none-any.whl
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\j_riv\pycharmprojects\jupyterproject\.venv\lib\site-packages (from yfinance) (4.3.8)
# Requirement already satisfied: pytz>=2022.5 in c:\users\j_riv\pycharmprojects\jupyterproject\.venv\lib\site-packages (from yfinance) (2025.2)
# Collecting frozendict>=2.3.4 (from yfinance)
#   Using cached frozendict-2.4.6-py313-none-any.whl.metadata (23 kB)
# Collecting peewee>=3.16.2 (from yfinance)
#   Using cached peewee-3.18.2-py3-none-any.whl
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\j_riv\pycharmprojects\jupyterproject\.venv\lib\site-packages (from yfinance) (4.13.4)
# Collecting curl_cffi>=0.7 (from yfinance)
#   Using cached curl_cffi-0.12.0-cp39-abi3-win_amd64.whl.metadata (15 kB)
# Collecting protobuf>=3.19.0 (from yfinance)
#   Using cached protobuf-6.31.1-cp310-abi3-win_amd64.whl.metadata (593 bytes)
# Collecting websockets>=13.0 (from yfinance)
#   Using cached websockets-15.0.1-cp313-cp313-win_amd64.whl.metadata (7.0 kB)
# Requirement already satisfied: soupsieve>1.2 in c:\users\j_riv\pycharmprojects\jupyterproject\.venv\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\j_riv\pycharmprojects\jupyterproject\.venv\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.14.1)
# Requirement already satisfied: cffi>=1.12.0 in c:\users\j_riv\pycharmprojects\jupyterproject\.venv\lib\site-packages (from curl_cffi>=0.7->yfinance) (1.17.1)
# Requirement already satisfied: certifi>=2024.2.2 in c:\users\j_riv\pycharmprojects\jupyterproject\.venv\lib\site-packages (from curl_cffi>=0.7->yfinance) (2025.7.14)
# Requirement already satisfied: pycparser in c:\users\j_riv\pycharmprojects\jupyterproject\.venv\lib\site-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance) (2.22)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\j_riv\pycharmprojects\jupyterproject\.venv\lib\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\j_riv\pycharmprojects\jupyterproject\.venv\lib\site-packages (from pandas>=1.3.0->yfinance) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\j_riv\pycharmprojects\jupyterproject\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\j_riv\pycharmprojects\jupyterproject\.venv\lib\site-packages (from requests>=2.31->yfinance) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\j_riv\pycharmprojects\jupyterproject\.venv\lib\site-packages (from requests>=2.31->yfinance) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\j_riv\pycharmprojects\jupyterproject\.venv\lib\site-packages (from requests>=2.31->yfinance) (2.5.0)
# Using cached yfinance-0.2.65-py2.py3-none-any.whl (119 kB)
# Using cached curl_cffi-0.12.0-cp39-abi3-win_amd64.whl (1.6 MB)
# Using cached frozendict-2.4.6-py313-none-any.whl (16 kB)
# Using cached protobuf-6.31.1-cp310-abi3-win_amd64.whl (435 kB)
# Using cached websockets-15.0.1-cp313-cp313-win_amd64.whl (176 kB)
# Installing collected packages: peewee, multitasking, websockets, protobuf, frozendict, curl_cffi, yfinance
#
#    ---------------------------------------- 0/7 [peewee]
#    ----------- ---------------------------- 2/7 [websockets]
#    ----------- ---------------------------- 2/7 [websockets]
#    ----------- ---------------------------- 2/7 [websockets]
#    ----------------- ---------------------- 3/7 [protobuf]
#    ----------------- ---------------------- 3/7 [protobuf]
#    ----------------- ---------------------- 3/7 [protobuf]
#    ----------------- ---------------------- 3/7 [protobuf]
#    ---------------------------- ----------- 5/7 [curl_cffi]
#    ---------------------------------- ----- 6/7 [yfinance]
#    ---------------------------------- ----- 6/7 [yfinance]
#    ---------------------------------------- 7/7 [yfinance]
#
# Successfully installed curl_cffi-0.12.0 frozendict-2.4.6 multitasking-0.0.12 peewee-3.18.2 protobuf-6.31.1 websockets-15.0.1 yfinance-0.2.65
# Requirement already satisfied: pandas in c:\users\j_riv\pycharmprojects\jupyterproject\.venv\lib\site-packages (2.3.1)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\j_riv\pycharmprojects\jupyterproject\.venv\lib\site-packages (from pandas) (2.3.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\j_riv\pycharmprojects\jupyterproject\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\j_riv\pycharmprojects\jupyterproject\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\j_riv\pycharmprojects\jupyterproject\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\j_riv\pycharmprojects\jupyterproject\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: requests in c:\users\j_riv\pycharmprojects\jupyterproject\.venv\lib\site-packages (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\j_riv\pycharmprojects\jupyterproject\.venv\lib\site-packages (from requests) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\j_riv\pycharmprojects\jupyterproject\.venv\lib\site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\j_riv\pycharmprojects\jupyterproject\.venv\lib\site-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\j_riv\pycharmprojects\jupyterproject\.venv\lib\site-packages (from requests) (2025.7.14)
# Collecting bs4
#   Using cached bs4-0.0.2-py2.py3-none-any.whl.metadata (411 bytes)
# Requirement already satisfied: beautifulsoup4 in c:\users\j_riv\pycharmprojects\jupyterproject\.venv\lib\site-packages (from bs4) (4.13.4)
# Requirement already satisfied: soupsieve>1.2 in c:\users\j_riv\pycharmprojects\jupyterproject\.venv\lib\site-packages (from beautifulsoup4->bs4) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\j_riv\pycharmprojects\jupyterproject\.venv\lib\site-packages (from beautifulsoup4->bs4) (4.14.1)
# Using cached bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Installing collected packages: bs4
# Successfully installed bs4-0.0.2
# Collecting plotly
#   Using cached plotly-6.2.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting narwhals>=1.15.1 (from plotly)
#   Using cached narwhals-2.0.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: packaging in c:\users\j_riv\pycharmprojects\jupyterproject\.venv\lib\site-packages (from plotly) (25.0)
# Using cached plotly-6.2.0-py3-none-any.whl (9.6 MB)
# Using cached narwhals-2.0.1-py3-none-any.whl (385 kB)
# Installing collected packages: narwhals, plotly
#
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    ---------------------------------------- 2/2 [plotly]
#
# Successfully installed narwhals-2.0.1 plotly-6.2.0
# Collecting html5lib
#   Using cached html5lib-1.1-py2.py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: six>=1.9 in c:\users\j_riv\pycharmprojects\jupyterproject\.venv\lib\site-packages (from html5lib) (1.17.0)
# Requirement already satisfied: webencodings in c:\users\j_riv\pycharmprojects\jupyterproject\.venv\lib\site-packages (from html5lib) (0.5.1)
# Using cached html5lib-1.1-py2.py3-none-any.whl (112 kB)
# Installing collected packages: html5lib
# Successfully installed html5lib-1.1
#           Date  Revenue
# 58  2010-09-30     31.0
# 59  2010-06-30     28.0
# 60  2010-03-31     21.0
# 61  2009-09-30     46.0
# 62  2009-06-30     27.0
#           Date  Revenue
# 61  2010-01-31   3524.0
# 62  2009-10-31   1835.0
# 63  2009-07-31   1739.0
# 64  2009-04-30   1981.0
# 65  2009-01-31   3492.0
